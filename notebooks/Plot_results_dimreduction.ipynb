# %% [markdown]
# # Plot of features

# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import utils

# %%
# PN : Putty-nosed
# BM : Blue Monkeys
# TT : Titi
# CB : Campbell
# CL : Colobus

call2species = {'1':'PN', '2':'PN', '3':'PN', '4':'PN',
                'A':'BM-Kenya', 'A*':'BM-Kenya', 'KA':'BM-Kenya', 'KATR':'BM-Kenya', 'Nscrm':'BM-Kenya', 'PY':'BM-Kenya', 'BO':'BM-Kenya',                        
                'h':'BM-Uganda', 'p':'BM-Uganda',
                'A_titi':'TT', 'B':'TT', 'BS':'TT', 'Bw':'TT',  'C':'TT', 'H':'TT', 'x':'TT',
                'H':'CB', 'K':'CB', 'K+':'CB', 'W':'CB', 'W+':'CB', 'K+/W+':'CB',
                'r':'CL', 's':'CL'}

file_name = "data/pca_dimension_reduction_features_20D.csv"
#file_name = "data/lda_dimension_reduction_features_20D.csv"
#file_name = "data/lstm_autoencoder_features_20D.csv"
#file_name = "data/lstm_embeddings_features_20D.csv"
#file_name = "data/tripletloss_embeddings_features_20D.csv"

features, labels =  utils.read_csv(file_name)

# %%
features_2D = utils.features_to_pandas_2D(features, labels, call2species)

# %%
utils.plot_labels(features_2D, file_name)
